# %%
import networkx as nx

# %% [markdown]
# ## Shortest Path
#
# - A common AI problem in logistics is to find the shortest path between two points in a graph. (Imagine Google Maps; the shortest route between two locations)
# - To find this pathfinding problem we make use of a weighted graph called **pathfinding graph**.
# - For a pathfinding graph, the weights would typically be represented with either the time or distance.

# %%
# edge, nodes, and weights
edgeList = [
    ['Udderslake','Rabbington',80],
    ['Rabbington', 'Beddleford',85],
    ['Beddleford','Wickbridge',173],
    ['Wickbridge','Dillchester',502],
    ['Dillchester','Reeshburg',84],
    ['Reeshburg','Udderslake',205],
    ['Wickbridge','Rydham',30],
    ['Rydham','Clamswood',183],
    ['Clamswood','Dillchester',167],
    ['Clamswood','Sheffelbrook',103],
    ['Sheffelbrook','Beddleford',217],
    ['Sheffelbrook','Bendon',186]
]

# %%
# creates an empty graph
g = nx.Graph()

# "graph, I want to add an edge"
# populate the graph with edges
for edge in edgeList:
    g.add_edge(edge[0],edge[1],weight=edge[2])

# %%
# Auto Position Nodes
nx.draw(g, pos = nx.spring_layout(g), with_labels=True)

# %%
# Calculating shortest path between two cities (Dijkstra's Algorithm)
shortestPath = nx.shortest_path(g, 'Udderslake', 'Rydham', weight = 'weight')
dist = nx.shortest_path_length(g, 'Udderslake', 'Rydham', weight = 'weight')
print('Shorted path is:', shortestPath, '\nWith total distance of', dist, 'km')
# Out:
# Shorted path is: ['Udderslake', 'Rabbington', 'Beddleford', 'Wickbridge', 'Rydham']
# With total distance of 368 km

# %%
# Caculates the shortest path between all pairs of cities
for paths in nx.all_pairs_dijkstra_path(g, weight = 'weight'):
    print(paths)
# Out:
# ('Udderslake', {'Udderslake': ['Udderslake'], 'Rabbington': ['Udderslake', 'Rabbington'], 'Reeshburg': ['Udderslake', 'Reeshburg'], 'Beddleford': ['Udderslake', 'Rabbington', 'Beddleford'], 'Wickbridge': ['Udderslake', 'Rabbington', 'Beddleford', 'Wickbridge'], 'Sheffelbrook': ['Udderslake', 'Rabbington', 'Beddleford', 'Sheffelbrook'], 'Dillchester': ['Udderslake', 'Reeshburg', 'Dillchester'], 'Clamswood': ['Udderslake', 'Reeshburg', 'Dillchester', 'Clamswood'], 'Rydham': ['Udderslake', 'Rabbington', 'Beddleford', 'Wickbridge', 'Rydham'], 'Bendon': ['Udderslake', 'Rabbington', 'Beddleford', 'Sheffelbrook', 'Bendon']})
# ('Rabbington', {'Rabbington': ['Rabbington'], 'Udderslake': ['Rabbington', 'Udderslake'], 'Beddleford': ['Rabbington', 'Beddleford'], 'Reeshburg': ['Rabbington', 'Udderslake', 'Reeshburg'], 'Wickbridge': ['Rabbington', 'Beddleford', 'Wickbridge'], 'Sheffelbrook': ['Rabbington', 'Beddleford', 'Sheffelbrook'], 'Dillchester': ['Rabbington', 'Udderslake', 'Reeshburg', 'Dillchester'], 'Rydham': ['Rabbington', 'Beddleford', 'Wickbridge', 'Rydham'], 'Clamswood': ['Rabbington', 'Beddleford', 'Sheffelbrook', 'Clamswood'], 'Bendon': ['Rabbington', 'Beddleford', 'Sheffelbrook', 'Bendon']})
# ('Beddleford', {'Beddleford': ['Beddleford'], 'Rabbington': ['Beddleford', 'Rabbington'], 'Wickbridge': ['Beddleford', 'Wickbridge'], 'Sheffelbrook': ['Beddleford', 'Sheffelbrook'], 'Udderslake': ['Beddleford', 'Rabbington', 'Udderslake'], 'Reeshburg': ['Beddleford', 'Rabbington', 'Udderslake', 'Reeshburg'], 'Dillchester': ['Beddleford', 'Rabbington', 'Udderslake', 'Reeshburg', 'Dillchester'], 'Rydham': ['Beddleford', 'Wickbridge', 'Rydham'], 'Clamswood': ['Beddleford', 'Sheffelbrook', 'Clamswood'], 'Bendon': ['Beddleford', 'Sheffelbrook', 'Bendon']})
# ('Wickbridge', {'Wickbridge': ['Wickbridge'], 'Beddleford': ['Wickbridge', 'Beddleford'], 'Dillchester': ['Wickbridge', 'Rydham', 'Clamswood', 'Dillchester'], 'Rydham': ['Wickbridge', 'Rydham'], 'Clamswood': ['Wickbridge', 'Rydham', 'Clamswood'], 'Rabbington': ['Wickbridge', 'Beddleford', 'Rabbington'], 'Sheffelbrook': ['Wickbridge', 'Rydham', 'Clamswood', 'Sheffelbrook'], 'Udderslake': ['Wickbridge', 'Beddleford', 'Rabbington', 'Udderslake'], 'Bendon': ['Wickbridge', 'Rydham', 'Clamswood', 'Sheffelbrook', 'Bendon'], 'Reeshburg': ['Wickbridge', 'Rydham', 'Clamswood', 'Dillchester', 'Reeshburg']})
# ('Dillchester', {'Dillchester': ['Dillchester'], 'Wickbridge': ['Dillchester', 'Clamswood', 'Rydham', 'Wickbridge'], 'Reeshburg': ['Dillchester', 'Reeshburg'], 'Clamswood': ['Dillchester', 'Clamswood'], 'Udderslake': ['Dillchester', 'Reeshburg', 'Udderslake'], 'Rydham': ['Dillchester', 'Clamswood', 'Rydham'], 'Sheffelbrook': ['Dillchester', 'Clamswood', 'Sheffelbrook'], 'Beddleford': ['Dillchester', 'Reeshburg', 'Udderslake', 'Rabbington', 'Beddleford'], 'Bendon': ['Dillchester', 'Clamswood', 'Sheffelbrook', 'Bendon'], 'Rabbington': ['Dillchester', 'Reeshburg', 'Udderslake', 'Rabbington']})
# ('Reeshburg', {'Reeshburg': ['Reeshburg'], 'Dillchester': ['Reeshburg', 'Dillchester'], 'Udderslake': ['Reeshburg', 'Udderslake'], 'Wickbridge': ['Reeshburg', 'Dillchester', 'Clamswood', 'Rydham', 'Wickbridge'], 'Clamswood': ['Reeshburg', 'Dillchester', 'Clamswood'], 'Rabbington': ['Reeshburg', 'Udderslake', 'Rabbington'], 'Rydham': ['Reeshburg', 'Dillchester', 'Clamswood', 'Rydham'], 'Sheffelbrook': ['Reeshburg', 'Dillchester', 'Clamswood', 'Sheffelbrook'], 'Beddleford': ['Reeshburg', 'Udderslake', 'Rabbington', 'Beddleford'], 'Bendon': ['Reeshburg', 'Dillchester', 'Clamswood', 'Sheffelbrook', 'Bendon']})
# ('Rydham', {'Rydham': ['Rydham'], 'Wickbridge': ['Rydham', 'Wickbridge'], 'Clamswood': ['Rydham', 'Clamswood'], 'Beddleford': ['Rydham', 'Wickbridge', 'Beddleford'], 'Dillchester': ['Rydham', 'Clamswood', 'Dillchester'], 'Sheffelbrook': ['Rydham', 'Clamswood', 'Sheffelbrook'], 'Rabbington': ['Rydham', 'Wickbridge', 'Beddleford', 'Rabbington'], 'Bendon': ['Rydham', 'Clamswood', 'Sheffelbrook', 'Bendon'], 'Udderslake': ['Rydham', 'Wickbridge', 'Beddleford', 'Rabbington', 'Udderslake'], 'Reeshburg': ['Rydham', 'Clamswood', 'Dillchester', 'Reeshburg']})
# ('Clamswood', {'Clamswood': ['Clamswood'], 'Rydham': ['Clamswood', 'Rydham'], 'Dillchester': ['Clamswood', 'Dillchester'], 'Sheffelbrook': ['Clamswood', 'Sheffelbrook'], 'Beddleford': ['Clamswood', 'Sheffelbrook', 'Beddleford'], 'Bendon': ['Clamswood', 'Sheffelbrook', 'Bendon'], 'Wickbridge': ['Clamswood', 'Rydham', 'Wickbridge'], 'Reeshburg': ['Clamswood', 'Dillchester', 'Reeshburg'], 'Udderslake': ['Clamswood', 'Dillchester', 'Reeshburg', 'Udderslake'], 'Rabbington': ['Clamswood', 'Sheffelbrook', 'Beddleford', 'Rabbington']})
# ('Sheffelbrook', {'Sheffelbrook': ['Sheffelbrook'], 'Clamswood': ['Sheffelbrook', 'Clamswood'], 'Beddleford': ['Sheffelbrook', 'Beddleford'], 'Bendon': ['Sheffelbrook', 'Bendon'], 'Rydham': ['Sheffelbrook', 'Clamswood', 'Rydham'], 'Dillchester': ['Sheffelbrook', 'Clamswood', 'Dillchester'], 'Rabbington': ['Sheffelbrook', 'Beddleford', 'Rabbington'], 'Wickbridge': ['Sheffelbrook', 'Clamswood', 'Rydham', 'Wickbridge'], 'Reeshburg': ['Sheffelbrook', 'Clamswood', 'Dillchester', 'Reeshburg'], 'Udderslake': ['Sheffelbrook', 'Beddleford', 'Rabbington', 'Udderslake']})
# ('Bendon', {'Bendon': ['Bendon'], 'Sheffelbrook': ['Bendon', 'Sheffelbrook'], 'Clamswood': ['Bendon', 'Sheffelbrook', 'Clamswood'], 'Beddleford': ['Bendon', 'Sheffelbrook', 'Beddleford'], 'Rydham': ['Bendon', 'Sheffelbrook', 'Clamswood', 'Rydham'], 'Dillchester': ['Bendon', 'Sheffelbrook', 'Clamswood', 'Dillchester'], 'Rabbington': ['Bendon', 'Sheffelbrook', 'Beddleford', 'Rabbington'], 'Wickbridge': ['Bendon', 'Sheffelbrook', 'Clamswood', 'Rydham', 'Wickbridge'], 'Reeshburg': ['Bendon', 'Sheffelbrook', 'Clamswood', 'Dillchester', 'Reeshburg'], 'Udderslake': ['Bendon', 'Sheffelbrook', 'Beddleford', 'Rabbington', 'Udderslake']})
